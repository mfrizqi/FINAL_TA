# %%
import joblib
import pickle
import pandas as pd

# %%
train = joblib.load('./p/0006/train_0006.pkl')
train
# Out:
#     nAcid   ALogP     ALogp2       AMR       apol  naAromAtom  nAromBond  \
# 55      0  0.2632   0.069274  108.5712  53.019481          16         18
# 20      0 -0.8571   0.734620  115.9860  60.628653          17         19
# 23      0  0.2952   0.087143  103.2506  51.439481          17         19
# 30      0  0.4300   0.184900  106.9381  51.245895          17         19
# 0       0  0.4097   0.167854  110.4259  55.335067          17         19
# 38      0 -0.7381   0.544792   87.1552  41.971930          16         18
# 37      0 -2.1531   4.635840  145.8341  79.623376           0          0
# 64      0  0.1833   0.033599  115.4565  57.094688          16         18
# 39      0 -0.3940   0.155236  146.2929  76.529790           0          0
# 59      0  0.5071   0.257150  113.0836  56.113067          16         18
# 17      0 -0.1424   0.020278  128.1819  65.489032          17         19
# 74      0  0.7019   0.492664  139.2996  68.470653          23         25
# ...

# %%
with open("./raw_0008_05_pickle.pkl","wb") as f:
    pickle.dump(rawdata,f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-fb49a02bfa83> in <module>
#       1 with open("./raw_0008_05_pickle.pkl","wb") as f:
# ----> 2     pickle.dump(rawdata,f)
#
# NameError: name 'rawdata' is not defined

# %%
desc = []
desc.append(pd.DataFrame(joblib.load('./pickle/with_temp/desc_5_raw.pkl')))
desc.append(pd.DataFrame(joblib.load('./pickle/with_temp/desc_10_raw.pkl')))
desc.append(pd.DataFrame(joblib.load('./pickle/with_temp/desc_15_raw.pkl')))
desc.append(pd.DataFrame(joblib.load('./pickle/with_temp/desc_20_raw.pkl')))
desc.append(pd.DataFrame(joblib.load('./pickle/with_temp/desc_25_raw.pkl')))
desc[4].sort_values(by='MSE')
# Out:
#          MSE                                           solution  \
# 7   0.129859  [90, 30, 56, 27, 1, 46, 0, 93, 95, 88, 32, 14,...
# 8   0.137457  [26, 4, 78, 0, 12, 75, 44, 85, 86, 5, 31, 89, ...
# 13  0.140496  [89, 47, 79, 37, 52, 30, 65, 45, 38, 6, 90, 23...
# 6   0.140646  [48, 70, 19, 29, 85, 94, 60, 39, 1, 52, 61, 79...
# 2   0.142342  [46, 22, 64, 58, 23, 92, 50, 47, 8, 52, 36, 33...
# 14  0.142518  [78, 40, 12, 8, 61, 34, 13, 76, 1, 97, 14, 46,...
# 12  0.145786  [17, 22, 86, 72, 90, 39, 16, 56, 9, 61, 79, 1,...
# 0   0.147352  [64, 52, 13, 27, 92, 35, 43, 71, 31, 4, 41, 48...
# 3   0.148035  [4, 24, 76, 36, 89, 25, 40, 57, 60, 13, 84, 62...
# 1   0.149342  [76, 11, 18, 97, 31, 68, 75, 98, 99, 38, 83, 9...
# 15  0.149683  [37, 85, 7, 78, 13, 97, 92, 11, 38, 72, 88, 55...
# 17  0.149857  [65, 74, 14, 84, 37, 58, 73, 96, 21, 83, 64, 8...
# 9   0.150920  [36, 8, 50, 95, 35, 82, 34, 18, 76, 22, 4, 52,...
# 5   0.157899  [31, 24, 45, 32, 47, 75, 51, 9, 48, 42, 0, 64,...
# ...

# %%
svr = []
svr.append(pd.DataFrame(joblib.load('./pickle/with_temp/r2_rbf.pkl')))
svr.append(pd.DataFrame(joblib.load('./pickle/with_temp/r2_linear.pkl')))
svr.append(pd.DataFrame(joblib.load('./pickle/with_temp/r2_poly.pkl')))
svr[0]
# Out:
#   desc     C  Gamma  Epsilon  r2_train   r2_test  \
# 0    5    10  scale      0.1  0.757695  0.540071
# 1   10   100   auto      0.1  0.712122  0.436360
# 2   15     1   auto      0.1  0.561745  0.259216
# 3   20  1000   auto      0.1  0.852230  0.346125
# 4   25  1000   auto      0.1  0.890801  0.186841
#
#                                           train_pred  \
# 0  [6.265343286035508, 7.174139167092239, 7.06668...
# 1  [6.11869472338147, 7.136738830093403, 6.806289...
# 2  [6.3573811891863485, 7.20714806190496, 6.85501...
# 3  [5.796483998985436, 7.148331529218026, 7.58022...
# 4  [5.927989066555758, 6.932343308044144, 7.42805...
#
#                                            test_pred
# 0  [6.154785226860104, 6.1107107098662174, 6.1220...
# 1  [6.235781104450549, 6.304794146267209, 6.38552...
# 2  [6.597937993516218, 6.7230886447131315, 6.7111...
# 3  [6.445278127403198, 6.647931380591003, 6.48139...
# 4  [6.717822549767154, 6.950129896993465, 6.76668...

# %%
descn = []
descn.append(pd.DataFrame(joblib.load('./pickle/with_temp/best_5desc.pkl')))
descn.append(pd.DataFrame(joblib.load('./pickle/with_temp/best_10desc.pkl')))
descn.append(pd.DataFrame(joblib.load('./pickle/with_temp/best_15desc.pkl')))
descn.append(pd.DataFrame(joblib.load('./pickle/with_temp/best_20desc.pkl')))
descn.append(pd.DataFrame(joblib.load('./pickle/with_temp/best_25desc.pkl')))
descn[3]
# Out:
#              0
# 0       MOMI-X
# 1       MOMI-R
# 2       GRAV-6
# 3    SpAbs_Dzp
# 4      VAdjMat
# 5   ETA_Beta_s
# 6       SpAD_D
# 7         SP-1
# 8         MWC2
# 9       DPSA-2
# 10        SHBa
# 11      DPSA-3
# 12        EE_D
# 13        sumI
# 14       ATS2s
# 15  SpMax6_Bhs
# 16      EE_Dzp
# 17      Zagreb
# 18       piPC2
# 19      WNSA-1
